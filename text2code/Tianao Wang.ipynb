# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd '/content/gdrive/My Drive/CSE538/project/text-to-code/Text2Code/concode-master'
# Out:
# /content/gdrive/My Drive/CSE538/project/text-to-code/Text2Code/concode-master

# %%
# !pip install antlr4-python3-runtime==4.6
# !pip install allennlp==0.3.0
# !pip install ipython==6.5
# Out:
# Collecting antlr4-python3-runtime==4.6
#   Downloading https://files.pythonhosted.org/packages/9c/29/c9348449b76ab8009aefa05817d394f646399d80a8494243377226b4fe31/antlr4-python3-runtime-4.6.tar.gz (110kB)
#      |████████████████████████████████| 112kB 10.5MB/s
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.6-cp36-none-any.whl size=140029 sha256=d18c674b1aed43aff899117a0186a5c1324469f1e207314353595e36eba366dc
#   Stored in directory: /root/.cache/pip/wheels/99/7d/48/b72576a896e1f04a53c03af00e4aeea646fa66005831228eb0
# Successfully built antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime
# Successfully installed antlr4-python3-runtime-4.6
# Collecting allennlp==0.3.0
#   Downloading https://files.pythonhosted.org/packages/64/ee/8d2a43dc686ee7920e3728f4e00a7d676b1fb83cf082e4768b62cbd4fea8/allennlp-0.3.0-py3-none-any.whl (392kB)
#      |████████████████████████████████| 399kB 10.8MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from allennlp==0.3.0) (4.41.1)
# Collecting cffi==1.11.2
#   Downloading https://files.pythonhosted.org/packages/dc/1e/b383fde1f0a14b6ef5a60f71797c778ea1ef8bb34b726cb57061c0542c58/cffi-1.11.2-cp36-cp36m-manylinux1_x86_64.whl (419kB)
#      |████████████████████████████████| 430kB 17.7MB/s
# Collecting typing
#   Downloading https://files.pythonhosted.org/packages/05/d9/6eebe19d46bd05360c9a9aae822e67a80f9242aabbfc58b641b957546607/typing-3.7.4.3.tar.gz (78kB)
#      |████████████████████████████████| 81kB 7.5MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from allennlp==0.3.0) (0.22.2.post1)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.6/dist-packages (from allennlp==0.3.0) (0.5.3)
# Collecting pytz==2017.3
#   Downloading https://files.pythonhosted.org/packages/a3/7f/e7d1acbd433b929168a4fb4182a2ff3c33653717195a26c1de099ad1ef29/pytz-2017.3-py2.py3-none-any.whl (511kB)
#      |████████████████████████████████| 512kB 22.4MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (from allennlp==0.3.0) (3.2.5)
# Collecting sanic==0.6.0
#   Downloading https://files.pythonhosted.org/packages/a8/6d/61051883ae6ed657b34fddacae8d5fc391cee86f57b93efc4c7b08a270d4/sanic-0.6.0-py3-none-any.whl (46kB)
#      |████████████████████████████████| 51kB 5.3MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from allennlp==0.3.0) (2.10.0)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.6/dist-packages (from allennlp==0.3.0) (1.0.0)
# Requirement already satisfied: requests>=2.18 in /usr/local/lib/python3.6/dist-packages (from allennlp==0.3.0) (2.23.0)
# Collecting awscli>=1.11.91
#   Downloading https://files.pythonhosted.org/packages/84/d0/6188cdd15bb39b9d9d31ae756d323f3ab61e96a689c40699bd63b69ef9fb/awscli-1.18.192-py2.py3-none-any.whl (3.5MB)
#      |████████████████████████████████| 3.5MB 36.9MB/s
# Collecting pyhocon==0.3.35
#   Downloading https://files.pythonhosted.org/packages/95/b9/72883593ce531e95ac8190e251ae6f5377eada69504248bf1aebfce4c5b4/pyhocon-0.3.35.tar.gz (94kB)
#      |████████████████████████████████| 102kB 11.3MB/s
# Collecting overrides
#   Downloading https://files.pythonhosted.org/packages/ff/b1/10f69c00947518e6676bbd43e739733048de64b8dd998e9c2d5a71f44c5d/overrides-3.1.0.tar.gz
# Collecting spacy<2.1,>=2.0
#   Downloading https://files.pythonhosted.org/packages/ae/6e/a89da6b5c83f8811e46e3a9270c1aed90e9b9ee6c60faf52b7239e5d3d69/spacy-2.0.18-cp36-cp36m-manylinux1_x86_64.whl (25.2MB)
#      |████████████████████████████████| 25.2MB 136kB/s
# Collecting argparse
#   Downloading https://files.pythonhosted.org/packages/f2/94/3af39d34be01a24a6e65433d19e107099374224905f1e0cc6bbe1fd22a2f/argparse-1.4.0-py2.py3-none-any.whl
# Collecting sanic-cors
#   Downloading https://files.pythonhosted.org/packages/2d/33/5e1776669aa62dd9c65e3513425077915acb1758d6b19f08f830f27ce9a8/Sanic_Cors-0.10.0.post3-py2.py3-none-any.whl
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.6/dist-packages (from allennlp==0.3.0) (2.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from allennlp==0.3.0) (1.4.1)
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.6/dist-packages (from allennlp==0.3.0) (2.7.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from allennlp==0.3.0) (1.18.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi==1.11.2->allennlp==0.3.0) (2.20)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->allennlp==0.3.0) (0.17.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk->allennlp==0.3.0) (1.15.0)
# Collecting ujson>=1.35
#   Downloading https://files.pythonhosted.org/packages/f1/84/e039c6ffc6603f2dfe966972d345d4f650a4ffd74b18c852ece645de12ac/ujson-4.0.1-cp36-cp36m-manylinux1_x86_64.whl (179kB)
#      |████████████████████████████████| 184kB 41.0MB/s
# Collecting websockets>=3.2
#   Downloading https://files.pythonhosted.org/packages/bb/d9/856af84843912e2853b1b6e898ac8b802989fcf9ecf8e8445a1da263bf3b/websockets-8.1-cp36-cp36m-manylinux2010_x86_64.whl (78kB)
#      |████████████████████████████████| 81kB 9.3MB/s
# Collecting uvloop>=0.5.3
#   Downloading https://files.pythonhosted.org/packages/41/48/586225bbb02d3bdca475b17e4be5ce5b3f09da2d6979f359916c1592a687/uvloop-0.14.0-cp36-cp36m-manylinux2010_x86_64.whl (3.9MB)
#      |████████████████████████████████| 3.9MB 40.3MB/s
# Collecting aiofiles>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/ba/21/df5eae4b6db2eb00d58428dd7f793ecbf99942fcafcea141cbf108fa72f4/aiofiles-0.6.0-py3-none-any.whl
# Collecting httptools>=0.0.9
#   Downloading https://files.pythonhosted.org/packages/b1/a6/dc1e7e8f4049ab70d52c9690ec10652e268ab2542853033cc1d539594102/httptools-0.1.1-cp36-cp36m-manylinux1_x86_64.whl (216kB)
#      |████████████████████████████████| 225kB 44.7MB/s
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.6/dist-packages (from jupyter->allennlp==0.3.0) (5.0.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.6/dist-packages (from jupyter->allennlp==0.3.0) (7.5.1)
# Requirement already satisfied: notebook in /usr/local/lib/python3.6/dist-packages (from jupyter->allennlp==0.3.0) (5.3.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from jupyter->allennlp==0.3.0) (4.10.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from jupyter->allennlp==0.3.0) (5.6.1)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.6/dist-packages (from jupyter->allennlp==0.3.0) (5.2.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18->allennlp==0.3.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18->allennlp==0.3.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18->allennlp==0.3.0) (2020.11.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18->allennlp==0.3.0) (1.24.3)
# Requirement already satisfied: PyYAML<5.4,>=3.10; python_version != "3.4" in /usr/local/lib/python3.6/dist-packages (from awscli>=1.11.91->allennlp==0.3.0) (3.13)
# Collecting rsa<=4.5.0,>=3.1.2; python_version != "3.4"
#   Downloading https://files.pythonhosted.org/packages/26/f8/8127fdda0294f044121d20aac7785feb810e159098447967a6103dedfb96/rsa-4.5-py2.py3-none-any.whl
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/69/79/e6afb3d8b0b4e96cefbdc690f741d7dd24547ff1f94240c997a26fa908d3/s3transfer-0.3.3-py2.py3-none-any.whl (69kB)
#      |████████████████████████████████| 71kB 8.1MB/s
# Collecting colorama<0.4.4,>=0.2.5; python_version != "3.4"
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Collecting docutils<0.16,>=0.10
#   Downloading https://files.pythonhosted.org/packages/22/cd/a6aa959dca619918ccb55023b4cb151949c64d4d5d55b3f4ffd7eee0c6e8/docutils-0.15.2-py3-none-any.whl (547kB)
#      |████████████████████████████████| 552kB 37.7MB/s
# Collecting botocore==1.19.32
#   Downloading https://files.pythonhosted.org/packages/4a/60/c61c8f5af78833f11bf7dabde251ab77406119de7553a35a1179c3444d4d/botocore-1.19.32-py2.py3-none-any.whl (7.0MB)
#      |████████████████████████████████| 7.0MB 33.9MB/s
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.6/dist-packages (from pyhocon==0.3.35->allennlp==0.3.0) (2.4.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.1,>=2.0->allennlp==0.3.0) (2.0.4)
# Collecting preshed<2.1.0,>=2.0.1
#   Downloading https://files.pythonhosted.org/packages/20/93/f222fb957764a283203525ef20e62008675fd0a14ffff8cc1b1490147c63/preshed-2.0.1-cp36-cp36m-manylinux1_x86_64.whl (83kB)
#      |████████████████████████████████| 92kB 9.2MB/s
# Collecting dill<0.3,>=0.2
#   Downloading https://files.pythonhosted.org/packages/fe/42/bfe2e0857bc284cbe6a011d93f2a9ad58a22cb894461b199ae72cfef0f29/dill-0.2.9.tar.gz (150kB)
#      |████████████████████████████████| 153kB 49.7MB/s
# Collecting plac<1.0.0,>=0.9.6
#   Downloading https://files.pythonhosted.org/packages/9e/9b/62c60d2f5bc135d2aa1d8c8a86aaf84edb719a59c7f11a4316259e61a298/plac-0.9.6-py2.py3-none-any.whl
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.1,>=2.0->allennlp==0.3.0) (1.0.4)
# Collecting regex==2018.01.10
#   Downloading https://files.pythonhosted.org/packages/76/f4/7146c3812f96fcaaf2d06ff6862582302626a59011ccb6f2833bb38d80f7/regex-2018.01.10.tar.gz (612kB)
#      |████████████████████████████████| 614kB 33.2MB/s
# Collecting thinc<6.13.0,>=6.12.1
#   Downloading https://files.pythonhosted.org/packages/db/a7/46640a46fd707aeb204aa4257a70974b6a22a0204ba703164d803215776f/thinc-6.12.1-cp36-cp36m-manylinux1_x86_64.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 29.3MB/s
# Collecting sanic-plugins-framework>=0.9.0
#   Downloading https://files.pythonhosted.org/packages/ca/f9/8b2dfad92df5fc37fb764c91b8a45754119ad6f3f9d289188d2bd6f6252f/Sanic_Plugins_Framework-0.9.4.post1-py2.py3-none-any.whl
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->allennlp==0.3.0) (50.3.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard->allennlp==0.3.0) (1.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.6/dist-packages (from tensorboard->allennlp==0.3.0) (0.10.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard->allennlp==0.3.0) (3.3.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->allennlp==0.3.0) (1.7.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->allennlp==0.3.0) (3.12.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard->allennlp==0.3.0) (0.4.2)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard->allennlp==0.3.0) (1.33.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard->allennlp==0.3.0) (1.17.2)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorboard->allennlp==0.3.0) (0.35.1)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.6/dist-packages (from qtconsole->jupyter->allennlp==0.3.0) (4.3.3)
# Requirement already satisfied: qtpy in /usr/local/lib/python3.6/dist-packages (from qtconsole->jupyter->allennlp==0.3.0) (1.9.0)
# Requirement already satisfied: jupyter-client>=4.1 in /usr/local/lib/python3.6/dist-packages (from qtconsole->jupyter->allennlp==0.3.0) (5.3.5)
# Requirement already satisfied: pyzmq>=17.1 in /usr/local/lib/python3.6/dist-packages (from qtconsole->jupyter->allennlp==0.3.0) (20.0.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from qtconsole->jupyter->allennlp==0.3.0) (2.6.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from qtconsole->jupyter->allennlp==0.3.0) (4.7.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from qtconsole->jupyter->allennlp==0.3.0) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets->jupyter->allennlp==0.3.0) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /usr/local/lib/python3.6/dist-packages (from ipywidgets->jupyter->allennlp==0.3.0) (5.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets->jupyter->allennlp==0.3.0) (5.0.8)
# Requirement already satisfied: tornado>=4 in /usr/local/lib/python3.6/dist-packages (from notebook->jupyter->allennlp==0.3.0) (5.1.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from notebook->jupyter->allennlp==0.3.0) (2.11.2)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from notebook->jupyter->allennlp==0.3.0) (0.9.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.6/dist-packages (from notebook->jupyter->allennlp==0.3.0) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->allennlp==0.3.0) (3.2.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->allennlp==0.3.0) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->allennlp==0.3.0) (0.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->allennlp==0.3.0) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->allennlp==0.3.0) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->allennlp==0.3.0) (0.8.4)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from jupyter-console->jupyter->allennlp==0.3.0) (1.0.18)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<=4.5.0,>=3.1.2; python_version != "3.4"->awscli>=1.11.91->allennlp==0.3.0) (0.4.8)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore==1.19.32->awscli>=1.11.91->allennlp==0.3.0) (2.8.1)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl
# Collecting msgpack<0.6.0,>=0.5.6
#   Downloading https://files.pythonhosted.org/packages/22/4e/dcf124fd97e5f5611123d6ad9f40ffd6eb979d1efdc1049e28a795672fcd/msgpack-0.5.6-cp36-cp36m-manylinux1_x86_64.whl (315kB)
#      |████████████████████████████████| 317kB 29.3MB/s
# Collecting cytoolz<0.10,>=0.9.0
#   Downloading https://files.pythonhosted.org/packages/36/f4/9728ba01ccb2f55df9a5af029b48ba0aaca1081bbd7823ea2ee223ba7a42/cytoolz-0.9.0.1.tar.gz (443kB)
#      |████████████████████████████████| 450kB 37.9MB/s
# Collecting msgpack-numpy<0.4.4
#   Downloading https://files.pythonhosted.org/packages/ad/45/464be6da85b5ca893cfcbd5de3b31a6710f636ccb8521b17bd4110a08d94/msgpack_numpy-0.4.3.2-py2.py3-none-any.whl
# Collecting wrapt<1.11.0,>=1.10.0
#   Downloading https://files.pythonhosted.org/packages/a0/47/66897906448185fcb77fc3c2b1bc20ed0ecca81a0f2f88eda3fc5a34fc3d/wrapt-1.10.11.tar.gz
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard->allennlp==0.3.0) (2.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->allennlp==0.3.0) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard->allennlp==0.3.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard->allennlp==0.3.0) (4.1.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from traitlets->qtconsole->jupyter->allennlp==0.3.0) (4.4.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->allennlp==0.3.0) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->allennlp==0.3.0) (0.7.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->allennlp==0.3.0) (0.8.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets->jupyter->allennlp==0.3.0) (2.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->notebook->jupyter->allennlp==0.3.0) (1.1.1)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /usr/local/lib/python3.6/dist-packages (from terminado>=0.8.1->notebook->jupyter->allennlp==0.3.0) (0.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->jupyter->allennlp==0.3.0) (20.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->jupyter->allennlp==0.3.0) (0.5.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.0->jupyter-console->jupyter->allennlp==0.3.0) (0.2.5)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from cytoolz<0.10,>=0.9.0->thinc<6.13.0,>=6.12.1->spacy<2.1,>=2.0->allennlp==0.3.0) (0.11.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard->allennlp==0.3.0) (3.4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->allennlp==0.3.0) (3.1.0)
# Building wheels for collected packages: typing, pyhocon, overrides, dill, regex, cytoolz, wrapt
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-cp36-none-any.whl size=26307 sha256=47322e762ee3131ffcedb1e2b6ff457342cc5435e0faeecf17f9ee394cda3808
#   Stored in directory: /root/.cache/pip/wheels/2d/04/41/8e1836e79581989c22eebac3f4e70aaac9af07b0908da173be
#   Building wheel for pyhocon (setup.py) ... done
#   Created wheel for pyhocon: filename=pyhocon-0.3.35-cp36-none-any.whl size=14125 sha256=d6e7241e4a20b737fa43948f80776165a7972b29227b1221801f303198f0e48e
#   Stored in directory: /root/.cache/pip/wheels/97/ea/cd/d2b70c1cfa9e6b1242709de5a64fd46be8982bc42be56d9390
#   Building wheel for overrides (setup.py) ... done
#   Created wheel for overrides: filename=overrides-3.1.0-cp36-none-any.whl size=10174 sha256=1e6a4b383d3079f76c0ecb8e13372fc0e8dc551f8c5780a02d162184ac1b2351
#   Stored in directory: /root/.cache/pip/wheels/5c/24/13/6ef8600e6f147c95e595f1289a86a3cc82ed65df57582c65a9
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.2.9-cp36-none-any.whl size=77406 sha256=8b4f077f656e38133143663598b9a6be6faad16ae100e1911b6dd522271e2cce
#   Stored in directory: /root/.cache/pip/wheels/5b/d7/0f/e58eae695403de585269f4e4a94e0cd6ca60ec0c202936fa4a
#   Building wheel for regex (setup.py) ... done
#   Created wheel for regex: filename=regex-2018.1.10-cp36-cp36m-linux_x86_64.whl size=548010 sha256=d658788c1d81c243d2c03bdbcc4e3745fb6e657e50aff589773d096644b13145
#   Stored in directory: /root/.cache/pip/wheels/74/17/3f/c77bba99efd74ba1a19862c9dd97f4b6d735e2826721dc00ff
#   Building wheel for cytoolz (setup.py) ... done
#   Created wheel for cytoolz: filename=cytoolz-0.9.0.1-cp36-cp36m-linux_x86_64.whl size=1247667 sha256=093511b0f3e9dbc131a4818b98327e7ca02358f9fbb3d1cbb509e0845913ac59
#   Stored in directory: /root/.cache/pip/wheels/88/f3/11/9817b001e59ab04889e8cffcbd9087e2e2155b9ebecfc8dd38
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.10.11-cp36-cp36m-linux_x86_64.whl size=65116 sha256=823c83ad26ffe57d336c21357733869de00c9ffb30ae6b95052fa79dd91e5ddc
#   Stored in directory: /root/.cache/pip/wheels/48/5d/04/22361a593e70d23b1f7746d932802efe1f0e523376a74f321e
# Successfully built typing pyhocon overrides dill regex cytoolz wrapt
# ERROR: tensorflow 2.3.0 has requirement wrapt>=1.11.1, but you'll have wrapt 1.10.11 which is incompatible.
# ERROR: rpy2 3.2.7 has requirement cffi>=1.13.1, but you'll have cffi 1.11.2 which is incompatible.
# ERROR: multiprocess 0.70.11.1 has requirement dill>=0.3.3, but you'll have dill 0.2.9 which is incompatible.
# ERROR: en-core-web-sm 2.2.5 has requirement spacy>=2.2.2, but you'll have spacy 2.0.18 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: botocore 1.19.32 has requirement urllib3<1.27,>=1.25.4; python_version != "3.4", but you'll have urllib3 1.24.3 which is incompatible.
# ERROR: sanic-plugins-framework 0.9.4.post1 has requirement sanic>=18.12.0, but you'll have sanic 0.6.0 which is incompatible.
# ERROR: sanic-cors 0.10.0.post3 has requirement sanic>=18.12.0, but you'll have sanic 0.6.0 which is incompatible.
# Installing collected packages: cffi, typing, pytz, ujson, websockets, uvloop, aiofiles, httptools, sanic, rsa, jmespath, botocore, s3transfer, colorama, docutils, awscli, pyhocon, overrides, preshed, dill, plac, regex, msgpack, cytoolz, msgpack-numpy, wrapt, thinc, spacy, argparse, sanic-plugins-framework, sanic-cors, allennlp
#   Found existing installation: cffi 1.14.3
#     Uninstalling cffi-1.14.3:
#       Successfully uninstalled cffi-1.14.3
#   Found existing installation: pytz 2018.9
#     Uninstalling pytz-2018.9:
#       Successfully uninstalled pytz-2018.9
#   Found existing installation: rsa 4.6
#     Uninstalling rsa-4.6:
#       Successfully uninstalled rsa-4.6
#   Found existing installation: docutils 0.16
#     Uninstalling docutils-0.16:
#       Successfully uninstalled docutils-0.16
#   Found existing installation: preshed 3.0.4
#     Uninstalling preshed-3.0.4:
#       Successfully uninstalled preshed-3.0.4
#   Found existing installation: dill 0.3.3
#     Uninstalling dill-0.3.3:
#       Successfully uninstalled dill-0.3.3
#   Found existing installation: plac 1.1.3
#     Uninstalling plac-1.1.3:
#       Successfully uninstalled plac-1.1.3
#   Found existing installation: regex 2019.12.20
#     Uninstalling regex-2019.12.20:
#       Successfully uninstalled regex-2019.12.20
#   Found existing installation: msgpack 1.0.0
#     Uninstalling msgpack-1.0.0:
#       Successfully uninstalled msgpack-1.0.0
#   Found existing installation: wrapt 1.12.1
#     Uninstalling wrapt-1.12.1:
#       Successfully uninstalled wrapt-1.12.1
#   Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# Successfully installed aiofiles-0.6.0 allennlp-0.3.0 argparse-1.4.0 awscli-1.18.192 botocore-1.19.32 cffi-1.11.2 colorama-0.4.3 cytoolz-0.9.0.1 dill-0.2.9 docutils-0.15.2 httptools-0.1.1 jmespath-0.10.0 msgpack-0.5.6 msgpack-numpy-0.4.3.2 overrides-3.1.0 plac-0.9.6 preshed-2.0.1 pyhocon-0.3.35 pytz-2017.3 regex-2018.1.10 rsa-4.5 s3transfer-0.3.3 sanic-0.6.0 sanic-cors-0.10.0.post3 sanic-plugins-framework-0.9.4.post1 spacy-2.0.18 thinc-6.12.1 typing-3.7.4.3 ujson-4.0.1 uvloop-0.14.0 websockets-8.1 wrapt-1.10.11
# Collecting ipython==6.5
#   Downloading https://files.pythonhosted.org/packages/f7/62/2fef7db3a7b75e8099c3d9db2630ae5ba0b9eefefd91f7497862393d90e8/ipython-6.5.0-py3-none-any.whl (748kB)
#      |████████████████████████████████| 757kB 9.5MB/s
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython==6.5) (2.6.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython==6.5) (50.3.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ipython==6.5) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from ipython==6.5) (4.3.3)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython==6.5) (4.8.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython==6.5) (0.8.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython==6.5) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.15 in /usr/local/lib/python3.6/dist-packages (from ipython==6.5) (1.0.18)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.6/dist-packages (from ipython==6.5) (0.17.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.6/dist-packages (from ipython==6.5) (0.2.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->ipython==6.5) (0.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->ipython==6.5) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython==6.5) (0.6.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.15->ipython==6.5) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from jedi>=0.10->ipython==6.5) (0.7.1)
# ERROR: google-colab 1.0.0 has requirement ipython~=5.5.0, but you'll have ipython 6.5.0 which is incompatible.
# Installing collected packages: ipython
#   Found existing installation: ipython 5.5.0
#     Uninstalling ipython-5.5.0:
#       Successfully uninstalled ipython-5.5.0
# Successfully installed ipython-6.5.0

# %%
# !python build.py -train_file concode/train_shuffled_with_path_and_id_concode.json -valid_file concode/valid_shuffled_with_path_and_id_concode.json -test_file concode/test_shuffled_with_path_and_id_concode.json -output_folder data -train_num 100000 -valid_num 2000
# Out:
# Namespace(output_folder='data', test_file='concode/test_shuffled_with_path_and_id_concode.json', train_file='concode/train_shuffled_with_path_and_id_concode.json', train_num=100000, valid_file='concode/valid_shuffled_with_path_and_id_concode.json', valid_num=2000)
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# tcmalloc: large alloc 1135779840 bytes == 0x49826000 @  0x7fe744a961e7 0x54484f 0x53d69a 0x536bf4 0x50a1cc 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7fe744693bf7 0x5b259a
# Total code vocab: 86329
# Total nl vocab: 50908
# Total didnt parse: 0
# Total code vocab: 4246
# Total nl vocab: 4602
# Total didnt parse: 0
# Total code vocab: 4224
# Total nl vocab: 4443
# Total didnt parse: 0

# %%
mkdir data/d_100k_762

# %%
# !python preprocess.py -train data/train.dataset -valid data/valid.dataset -save_data data/d_100k_762/concode -train_max 50000 -valid_max 2000
# Out:
# Namespace(names_min_frequency=7, save_data='data/d_100k_762/concode', seq2seq_words_min_frequency=6, src_seq_length=200, tgt_seq_length=150, tgt_words_min_frequency=2, train='data/train.dataset', train_max=50000, valid='data/valid.dataset', valid_max=2000)
# tcmalloc: large alloc 1135779840 bytes == 0x24c0000 @  0x7f474dd9a1e7 0x59211c 0x4ca6a4 0x566b8a 0x5a4cd1 0x5a5dca 0x4cdfd2 0x5669e2 0x5a4cd1 0x5a5f8e 0x5bd078 0x50a12f 0x50beb4 0x507be4 0x508ec2 0x594a01 0x549e8f 0x5515c1 0x5a9dac 0x50a433 0x50cc96 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7f474d997bf7 0x5b259a
# Done: 47300
# Done: 47400
# Done: 47500
# Done: 47600
# Done: 47600
# Done: 47700
# Done: 47800
# Done: 47900
# Done: 47900
# Done: 48000
# Done: 48000
# Done: 48100
# Done: 48200
# Done: 48300
# Done: 48400
# Done: 48500
# Done: 48600
# Done: 48700
# Done: 48800
# Done: 48800
# Done: 48900
# Done: 49000
# Done: 49100
# Done: 49200
# Done: 49300
# Done: 49400
# Done: 49500
# Done: 49600
# Done: 49700
# Done: 49800
# Done: 49900
# Building Vocab...
# Maximum code toks: 153
# Done: 0
# Done: 0
# Done: 0
# Done: 100
# Done: 200
# Done: 300
# Done: 400
# Done: 500
# Done: 600
# Done: 700
# Done: 800
# Done: 800
# Done: 900
# Done: 1000
# Done: 1100
# Done: 1200
# Done: 1200
# Done: 1200
# Done: 1300
# Done: 1400
# Done: 1500
# Done: 1600
# Done: 1700
# Training stats
# Average NL length: 13.76074
# Average Code Characters: 120.2681
# Average Code Tokens : 26.74244
# Max Code Tokens : 134
# Average AST Nodes: 79.86994
# Max AST Nodes: 7
# Percent getters: 0.16804
# Percent setters: 0.03366
# Number of variable copies: 67.362, function copies: 16.28, source copies: 0.22, Type copies: 9.222
# Building Valid...
# Valid stats
# Average NL length: 14.690220463538722
# Average Code Characters: 135.5161107970605
# Average Code Tokens : 30.58168456755229
# Max Code Tokens : 137
# Average AST Nodes: 91.57320520067834
# Max AST Nodes: 7
# Percent getters: 0.12492933860938384
# Percent setters: 0.03730921424533635
# Number of variable copies: 60.938383267382704, function copies: 20.463538722442056, source copies: 0.395703787450537, Type copies: 15.488976823063878
# Saving train/valid/vocabs
# Vocab Statistics
# names_combined : 19977/249336
# types : 14301/42190
# nt : 150/150
# seq2seq : 22306/45002
# code : 11127/25004
# next_rules : 11373/52987
# prev_rules : 338/338

# %%
! /opt/bin/nvidia-smi
# Out:
# Mon Nov 30 18:06:32 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip3 install http://download.pytorch.org/whl/cu90/torch-0.3.0-cp36-cp36m-linux_x86_64.whl
# Out:
# Collecting torch==0.3.0
#   Downloading http://download.pytorch.org/whl/cu90/torch-0.3.0-cp36-cp36m-linux_x86_64.whl (632.9MB)
#      |████████████████████████████████| 632.9MB 1.2MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from torch==0.3.0) (3.13)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch==0.3.0) (1.18.5)
# ERROR: torchvision 0.8.1+cu101 has requirement torch==1.7.0, but you'll have torch 0.3.0 which is incompatible.
# ERROR: fastai 1.0.61 has requirement torch>=1.0.0, but you'll have torch 0.3.0 which is incompatible.
# Installing collected packages: torch
#   Found existing installation: torch 1.7.0+cu101
#     Uninstalling torch-1.7.0+cu101:
#       Successfully uninstalled torch-1.7.0+cu101
# Successfully installed torch-0.3.0

# %%
# !pip3 install torchvision==0.2.0
# Out:
# Collecting torchvision==0.2.0
#   Downloading https://files.pythonhosted.org/packages/e9/c9/f4eb36734bffd36eb8095247d816cbe6aeca0a2b9218b78678288edfdb92/torchvision-0.2.0-py2.py3-none-any.whl (48kB)
#      |████████████████████████████████| 51kB 5.0MB/s
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.2.0) (7.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision==0.2.0) (1.18.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchvision==0.2.0) (0.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision==0.2.0) (1.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from torch->torchvision==0.2.0) (3.13)
# ERROR: fastai 1.0.61 has requirement torch>=1.0.0, but you'll have torch 0.3.0 which is incompatible.
# Installing collected packages: torchvision
#   Found existing installation: torchvision 0.8.1+cu101
#     Uninstalling torchvision-0.8.1+cu101:
#       Successfully uninstalled torchvision-0.8.1+cu101
# Successfully installed torchvision-0.2.0

# %%
import torch
torch.__version__
# Out:
# '0.3.1'

# %% [markdown]
# # LSTM

# %%
# !python train.py -dropout 0.5 -data data/d_100k_762/concode -save_model data/d_100k_762/s2s -epochs 30 -learning_rate 0.001 -seed 1123 -enc_layers 2 -dec_layers 2 -batch_size 20 -src_word_vec_size 1024 -tgt_word_vec_size 512 -rnn_size 1024 -encoder_type regular -decoder_type regular -copy_attn

# %% [markdown]
# # GRU

# %%
! /opt/bin/nvidia-smi
# Out:
# Tue Dec  1 10:06:02 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
# torch.backends.cudnn.enabled = False
# Out:
# 1.7.0+cu101
# 10.1

# %%
ls
# Out:
#  Beam.py                      GlobalAttention.py   S2SModel.py
#  build.py                     java/                Statistics.py
#  concode@                     predict.ipy         'Tianao Wang.ipynb'
#  ConcodeDecoder.py            preprocess.py        tools/
#  ConcodeEncoder.py            ProdDecoder.py       Trainer.py
#  CopyGenerator.py             __pycache__/         train.py
# 'Copy of Tianao Wang.ipynb'   README.md            translate.py
#  data/                        RegularDecoder.py    Tree.py
#  decoders.py                  RegularEncoder.py    UtilClass.py

# %%
# !python train.py -dropout 0.5 -data data/d_100k_762/concode -save_model data/d_100k_762/s2s -epochs 30 -learning_rate 0.001 -seed 1123 -enc_layers 2 -dec_layers 2 -batch_size 50 -src_word_vec_size 1024 -tgt_word_vec_size 512 -rnn_size 1024 -encoder_type regular -decoder_type regular -copy_attn
# Out:
# Loading train set
#
# Loaded Train :
# Loaded datasets:
# Namespace(batch_size=50, brnn=False, copy_attn=True, data='data/d_100k_762/concode', dec_layers=2, decoder_rnn_size=1024, decoder_type='regular', dropout=0.5, enc_layers=2, encoder_type='regular', epochs=30, learning_rate=0.001, learning_rate_decay=0.8, max_camel=20, max_grad_norm=5, method_names=False, nocamel=False, num_gpus=None, report_every=500, rnn_size=1024, save_model='data/d_100k_762/s2s', seed=1123, src_word_vec_size=1024, start_epoch=None, tgt_word_vec_size=512, train_from='', trunc=-1, twostep=False, var_names=False)
# Traceback (most recent call last):
#   File "train.py", line 138, in <module>
#     main()
#   File "train.py", line 129, in main
#     model = S2SModel(opt, vocabs)
#   File "/content/gdrive/My Drive/CSE538/project/text-to-code/Text2Code/concode-master/S2SModel.py", line 45, in __init__
#     self.cuda()
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 216, in cuda
#     return self._apply(lambda t: t.cuda(device))
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 146, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 146, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py", line 123, in _apply
#     self.flatten_parameters()
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py", line 102, in flatten_parameters
#     fn.rnn_desc = rnn.init_rnn_descriptor(fn, handle)
#   File "/usr/local/lib/python3.6/dist-packages/torch/backends/cudnn/rnn.py", line 42, in init_rnn_descriptor
#     cudnn.DropoutDescriptor(handle, dropout_p, fn.dropout_seed)
#   File "/usr/local/lib/python3.6/dist-packages/torch/backends/cudnn/__init__.py", line 207, in __init__
#     self._set(dropout, seed)
#   File "/usr/local/lib/python3.6/dist-packages/torch/backends/cudnn/__init__.py", line 232, in _set
#     ctypes.c_ulonglong(seed),
#   File "/usr/local/lib/python3.6/dist-packages/torch/backends/cudnn/__init__.py", line 283, in check_error
#     raise CuDNNError(status)
# torch.backends.cudnn.CuDNNError: 8: b'CUDNN_STATUS_EXECUTION_FAILED'

# %%
import torch
torch.backends.cudnn.enabled = False

# %%
# !ipython predict.ipy -- -start 1 -end 3 -beam 3 -models_dir data/d_100k_762/concode -test_file data/valid.dataset -tgt_len 500
# Out:
# [TerminalIPythonApp] WARNING | GUI event loop or pylab initialization failed
#
# UnknownBackendTraceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    3052         # Now we must activate the gui pylab wants to use, and fix %run to take
#    3053         # plot updates into account
# -> 3054         self.enable_gui(gui)
#    3055         self.magics_manager.registry['ExecutionMagics'].default_runner = \
#    3056             pt.mpl_runner(self.safe_execfile)
#
# /usr/local/lib/python3.6/dist-packages/IPython/terminal/interactiveshell.py in enable_gui(self, gui)
#     504         if gui:
#     505             self.active_eventloop, self._inputhook =\
# --> 506                 get_inputhook_name_and_func(gui)
#     507         else:
#     508             self.active_eventloop = self._inputhook = None
#
# /usr/local/lib/python3.6/dist-packages/IPython/terminal/pt_inputhooks/__init__.py in get_inputhook_name_and_func(gui)
#      36
#      37     if gui not in backends:
# ---> 38         raise UnknownBackend(gui)
#      39
#      40     if gui in aliases:
#
# UnknownBackend: No event loop integration for 'inline'. Supported event loops are: qt, qt4, qt5, gtk, gtk2, gtk3, tk, wx, pyglet, glut, osx
# ['data/d_100k_762/concode/model_acc_80.53_ppl_1.97_e1.pt']
# model_acc_80.53_ppl_1.97_e1.pt
# rm: cannot remove 'data/d_100k_762/concode/preds/model_acc_80.53_ppl_1.97_e1.pt.nl.prediction*': No such file or directory
# Maximum code toks: 153
# Done: 100
# Done: 200
# Done: 300
# Done: 400
# Done: 500
# Done: 600
# Done: 700
# Done: 800
# Done: 900
# Done: 1000
# Done: 1100
# Done: 1200
# Done: 1300
# Done: 1400
# Done: 1500
# Done: 1600
# Done: 1700
# Done: 1800
# Done: 1900
# Computed batched in :6.958146037000001 secs
# Total test: 2000/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:325: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greately increasing memory usage. To compact weights again call flatten_parameters().
#   result = self.forward(*input, **kwargs)
# /content/gdrive/My Drive/CSE538/project/text-to-code/Text2Code/concode-master/UtilClass.py:95: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greately increasing memory usage. To compact weights again call flatten_parameters().
#   out = super(BottleLSTMHelper, self).forward(input.view(size[0]*size[1], size[2], -1), lengths.view(-1))
# /content/gdrive/My Drive/CSE538/project/text-to-code/Text2Code/concode-master/ConcodeDecoder.py:87: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greately increasing memory usage. To compact weights again call flatten_parameters().
#   rnn_output, prev_hidden = self.decoder_rnn(torch.cat((nt, rule, parent_rule, parent_states), 2), decState.hidden)
# ['14.38,65.7,41.9,23.0,13.1 (BP=0.477, ratio=0.574, hyp_len=35125, ref_len=61162)']
# ['4.1']
# Best BLEU so far is: 14.38 - Exact is 4.1 - on epoch 1
# BLEU is 14.38 - Best Exact so far: is 4.1 - on epoch 1
# ['data/d_100k_762/concode/model_acc_81.27_ppl_1.93_e2.pt']
# model_acc_81.27_ppl_1.93_e2.pt
# rm: cannot remove 'data/d_100k_762/concode/preds/model_acc_81.27_ppl_1.93_e2.pt.nl.prediction*': No such file or directory
# Maximum code toks: 153
# Done: 100
# Done: 200
# Done: 300
# Done: 400
# Done: 500
# Done: 600
# Done: 700
# Done: 800
# Done: 900
# Done: 1000
# Done: 1100
# Done: 1200
# Done: 1300
# Done: 1400
# Done: 1500
# Done: 1600
# Done: 1700
# Done: 1800
# Done: 1900
# Computed batched in :6.9433152279999995 secs
# Total test: 2000/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:325: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greately increasing memory usage. To compact weights again call flatten_parameters().
#   result = self.forward(*input, **kwargs)
# /content/gdrive/My Drive/CSE538/project/text-to-code/Text2Code/concode-master/UtilClass.py:95: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greately increasing memory usage. To compact weights again call flatten_parameters().
#   out = super(BottleLSTMHelper, self).forward(input.view(size[0]*size[1], size[2], -1), lengths.view(-1))
# /content/gdrive/My Drive/CSE538/project/text-to-code/Text2Code/concode-master/ConcodeDecoder.py:87: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greately increasing memory usage. To compact weights again call flatten_parameters().
#   rnn_output, prev_hidden = self.decoder_rnn(torch.cat((nt, rule, parent_rule, parent_states), 2), decState.hidden)
# ['15.76,66.0,42.5,24.0,14.3 (BP=0.504, ratio=0.593, hyp_len=36279, ref_len=61162)']
# ['4.65']
# Best BLEU so far is: 15.76 - Exact is 4.65 - on epoch 2
# BLEU is 15.76 - Best Exact so far: is 4.65 - on epoch 2
# ['data/d_100k_762/concode/model_acc_81.50_ppl_1.91_e3.pt']
# model_acc_81.50_ppl_1.91_e3.pt
# rm: cannot remove 'data/d_100k_762/concode/preds/model_acc_81.50_ppl_1.91_e3.pt.nl.prediction*': No such file or directory
# Maximum code toks: 153
# Done: 100
# Done: 200
# Done: 300
# Done: 400
# Done: 500
# Done: 600
# Done: 700
# Done: 800
# Done: 900
# Done: 1000
# Done: 1100
# Done: 1200
# Done: 1300
# Done: 1400
# Done: 1500
# Done: 1600
# Done: 1700
# Done: 1800
# Done: 1900
# Computed batched in :6.505193196999999 secs
# Total test: 2000/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:325: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greately increasing memory usage. To compact weights again call flatten_parameters().
#   result = self.forward(*input, **kwargs)
# /content/gdrive/My Drive/CSE538/project/text-to-code/Text2Code/concode-master/UtilClass.py:95: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greately increasing memory usage. To compact weights again call flatten_parameters().
#   out = super(BottleLSTMHelper, self).forward(input.view(size[0]*size[1], size[2], -1), lengths.view(-1))
# /content/gdrive/My Drive/CSE538/project/text-to-code/Text2Code/concode-master/ConcodeDecoder.py:87: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greately increasing memory usage. To compact weights again call flatten_parameters().
#   rnn_output, prev_hidden = self.decoder_rnn(torch.cat((nt, rule, parent_rule, parent_states), 2), decState.hidden)
# ['16.86,64.0,40.7,23.1,13.3 (BP=0.564, ratio=0.636, hyp_len=38878, ref_len=61162)']
# ['4.6']
# Best BLEU so far is: 16.86 - Exact is 4.6 - on epoch 3
# BLEU is 15.76 - Best Exact so far: is 4.65 - on epoch 2
